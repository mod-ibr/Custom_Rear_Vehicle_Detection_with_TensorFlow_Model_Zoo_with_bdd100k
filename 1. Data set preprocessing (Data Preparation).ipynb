# %% [markdown]
# # Data preprocessing (Data Preparation)

# %% [markdown]
# ### Use Case:
# ##### - Our data set is from [BDD100K](https://www.bdd100k.com/) contains 10 classes at that writing time, we used bdd100K dataset for detection and its 2020_label.
#
# ##### - The generated 2020 labels 'Annotations' for the BDD100K dataset are for detection and other purposes, That annotations are in one JSON format file, so we will separate the data of each image in that JSON format file into multiple files equal to the images data set length in XML VOC  format (each image will have its corresponding XML file).
#
# ##### - We will take just the data set which contains cars, buses, and trucks, and move other images to the 'unrelated images ' folder.
#
# ##### - Also, there are maybe some images that have no labels ever, so we'll move them to the same directory 'unrelated images'.

# %% [markdown]
# ### **Agenda:**
#
# ##### 1.  prepare a function to write the required XML file, depending on the XML file generated from [LabelImg ](https://github.com/heartexlabs/labelImg)just to be a reference for us.
#
#
# ##### 2. Looping over a JSON file to get each image's data, and then pass that data to the XML_generatetion function.
#
#
# ##### 3. To insure that each image has its annotation file, we'll Looping over the data set folder to remove any image that doesn't has a similar annotation XML file.

# %%
import os,shutil,json
import xml.etree.ElementTree as ET

# %% [markdown]
# ## XML generatetion

# %%
def XML_generatetion(f_name,labels,data_set_path,unrelated_images_folder_path):
    '''
    This function creates an XML VOC file for cars, buses, and trucks.
    It takes the file name as a string and labels as a list.
    If that list does not contain one of the cars, buses, or trucks, 
    it will get into your data set file, remove that unnecessary file,
    and move it to a new folder called the unrelated images folder.
    '''
    is_file_related = False # is containes car,bus,truck ?
    round_ratio = 3 #round_ratio for BBoxes
    path = 'I:\\Proposel\\CV\\tf\\val\\' 
    f = f_name+'.jpg'
    # Concatenate the two strings
    full_path = path + f
    
    # create the root element
    root = ET.Element("annotation")

    # add sub-elements
    folder = ET.SubElement(root, "folder")
    folder.text = "val"

    filename = ET.SubElement(root, "filename")
    filename.text = f

    path = ET.SubElement(root, "path")
    path.text = full_path

    source = ET.SubElement(root, "source")
    database = ET.SubElement(source, "database")
    database.text = "Unknown"

    size = ET.SubElement(root, "size")
    width = ET.SubElement(size, "width")
    width.text = "1280"
    height = ET.SubElement(size, "height")
    height.text = "720"
    depth = ET.SubElement(size, "depth")
    depth.text = "3"

    segmented = ET.SubElement(root, "segmented")
    segmented.text = "0"
    
    # add the objects
    for label in labels:
        if label['category']  in ['car','truck','bus']:
            is_file_related = True
            category = label['category']
            x1,y1,x2,y2 = round(label['box2d']['x1'],round_ratio),round(label['box2d']['y1'],round_ratio),round(label['box2d']['x2'],round_ratio),round(label['box2d']['y2'],round_ratio)
            obj = ET.SubElement(root, "object")
            name = ET.SubElement(obj, "name")
            name.text = category
            pose = ET.SubElement(obj, "pose")
            pose.text = "Unspecified"
            truncated = ET.SubElement(obj, "truncated")
            truncated.text = "0"
            difficult = ET.SubElement(obj, "difficult")
            difficult.text = "0"
            bndbox = ET.SubElement(obj, "bndbox")
            xmin = ET.SubElement(bndbox, "xmin")
            xmin.text = str(x1)
            ymin = ET.SubElement(bndbox, "ymin")
            ymin.text = str(y1)
            xmax = ET.SubElement(bndbox, "xmax")
            xmax.text = str(x2)
            ymax = ET.SubElement(bndbox, "ymax")
            ymax.text = str(y2)
        
            
    
              
    if is_file_related:
        # write to file and save it
        tree = ET.ElementTree(root)
        save_name = 'annotations\\'+f_name+'.xml'
        tree.write(save_name)
    else:
        # Go to dataset folder and move that image to unrelated_images_folder_path
        image = data_set_path +'\\'+f_name+'.jpg'
        # Move the file to the new directory
        shutil.move(image, unrelated_images_folder_path)   
    print('--------------------- Finish XML generator Function')

# %% [markdown]
# ## Looping over a JSON file to get each image data and pass it to XML generation.

# %%
# Load the JSON file into a Python object
with open('det_val.json') as f:
    data = json.load(f)

# Define the name of unrelated images folder.
annotations = 'annotations'
unrelated_images_folder_path = 'unrelated_images_folder'
# Create the new folder
os.mkdir(annotations)
os.mkdir(unrelated_images_folder)

# Iterate over the elements
counter_indicator = 0
counter_Error_indicator = 0
for element in data:
    try:
        counter_indicator = counter_indicator+1
        f_name = element['name'].split('.')[0]
        labels = element['labels']
        print('======================================')
        print('File number : ', counter_indicator)
        print('File Name : ', f_name)
        XML_generatetion(f_name=f_name, labels=labels, data_set_path='val',
                            unrelated_images_folder_path=unrelated_images_folder_path)
    except:
        counter_Error_indicator = counter_Error_indicator+1
        print('#######################################')
        print('ERROR At Image : ', f_name)
        continue
print("counter_Error_indicator : ", counter_Error_indicator)
# Out:
# ======================================
# File number :  1
# File Name :  b1c66a42-6f7d68ca
# --------------------- Finish XML generator Function
# ======================================
# File number :  2
# File Name :  b1c81faa-3df17267
# --------------------- Finish XML generator Function
# ======================================
# File number :  3
# File Name :  b1c81faa-c80764c5
# --------------------- Finish XML generator Function
# ======================================
# File number :  4
# File Name :  b1c9c847-3bda4659
# --------------------- Finish XML generator Function
# ======================================
# File number :  5
# File Name :  b1ca2e5d-84cf9134
# --------------------- Finish XML generator Function
# ======================================
# File number :  6
# File Name :  b1ca8418-84a133a0
# --------------------- Finish XML generator Function
# ======================================
# File number :  7
# File Name :  b1cac6a7-04e33135
# --------------------- Finish XML generator Function
# ======================================
# File number :  8
# File Name :  b1cd1e94-26dd524f
# --------------------- Finish XML generator Function
# ======================================
# File number :  9
# File Name :  b1cd1e94-549d0bfe
# --------------------- Finish XML generator Function
# ======================================
# File number :  10
# File Name :  b1ceb32e-3f481b43
# --------------------- Finish XML generator Function
# ======================================
# File number :  11
# File Name :  b1ceb32e-51852abe
# --------------------- Finish XML generator Function
# ======================================
# File number :  12
# File Name :  b1ceb32e-813f84b2
# --------------------- Finish XML generator Function
# ======================================
# File number :  13
# File Name :  b1ceb32e-a106591d
# --------------------- Finish XML generator Function
# ======================================
# File number :  14
# File Name :  b1cebfb7-284f5117
# --------------------- Finish XML generator Function
# ======================================
# File number :  15
# File Name :  b1d0091f-75824d0d
# --------------------- Finish XML generator Function
# ======================================
# File number :  16
# File Name :  b1d0091f-f2c2d2ae
# --------------------- Finish XML generator Function
# ======================================
# File number :  17
# File Name :  b1d0a191-03dcecc2
# --------------------- Finish XML generator Function
# ======================================
# File number :  18
# File Name :  b1d0a191-06deb55d
# --------------------- Finish XML generator Function
# ======================================
# File number :  19
# File Name :  b1d0a191-28f0e779
# --------------------- Finish XML generator Function
# ======================================
# File number :  20
# File Name :  b1d0a191-2ed2269e
# --------------------- Finish XML generator Function
# ======================================
# File number :  21
# File Name :  b1d0a191-5490450b
# --------------------- Finish XML generator Function
# ======================================
# File number :  22
# File Name :  b1d0a191-65deaeef
# --------------------- Finish XML generator Function
# ======================================
# File number :  23
# File Name :  b1d0a191-de8948f6
# --------------------- Finish XML generator Function
# ======================================
# File number :  24
# File Name :  b1d10d08-5b108225
# --------------------- Finish XML generator Function
# ======================================
# File number :  25
# File Name :  b1d10d08-743fd86c
# --------------------- Finish XML generator Function
# ======================================
# File number :  26
# File Name :  b1d10d08-c35503b8
# --------------------- Finish XML generator Function
# ======================================
# File number :  27
# File Name :  b1d10d08-da110fcb
# --------------------- Finish XML generator Function
# ======================================
# File number :  28
# File Name :  b1d10d08-ec660956
# --------------------- Finish XML generator Function
# ======================================
# File number :  29
# File Name :  b1d22449-117aa773
# --------------------- Finish XML generator Function
# ======================================
# File number :  30
# File Name :  b1d22449-15fb948f
# --------------------- Finish XML generator Function
# ======================================
# File number :  31
# File Name :  b1d22ed6-f1cac061
# --------------------- Finish XML generator Function
# ======================================
# File number :  32
# File Name :  b1d3907b-2278601b
# --------------------- Finish XML generator Function
# ======================================
# File number :  33
# File Name :  b1d4b62c-60aab822
# --------------------- Finish XML generator Function
# ======================================
# File number :  34
# File Name :  b1d4b62c-89eeb5d3
# --------------------- Finish XML generator Function
# ======================================
# File number :  35
# File Name :  b1d4b62c-d9805029
# --------------------- Finish XML generator Function
# ======================================
# File number :  36
# File Name :  b1d59b1f-a38aec79
# --------------------- Finish XML generator Function
# ======================================
# File number :  37
# File Name :  b1d7b3ac-0bdb47dc
# --------------------- Finish XML generator Function
# ======================================
# File number :  38
# File Name :  b1d7b3ac-2a92e19f
# --------------------- Finish XML generator Function
# ======================================
# File number :  39
# File Name :  b1d7b3ac-36f2d3b7
# --------------------- Finish XML generator Function
# ======================================
# File number :  40
# File Name :  b1d7b3ac-5744370e
# --------------------- Finish XML generator Function
# ======================================
# File number :  41
# File Name :  b1d7b3ac-5af8623b
# --------------------- Finish XML generator Function
# ======================================
# File number :  42
# File Name :  b1d7b3ac-995f9d8a
# --------------------- Finish XML generator Function
# ======================================
# File number :  43
# File Name :  b1d7b3ac-9e14f05f
# --------------------- Finish XML generator Function
# ======================================
# File number :  44
# File Name :  b1d7b3ac-afa57f22
# --------------------- Finish XML generator Function
# ======================================
# File number :  45
# File Name :  b1d8735d-eee9f184
# --------------------- Finish XML generator Function
# ======================================
# File number :  46
# File Name :  b1d968b9-563405f4
# --------------------- Finish XML generator Function
# ======================================
# File number :  47
# File Name :  b1d968b9-ce42734f
# --------------------- Finish XML generator Function
# ======================================
# File number :  48
# File Name :  b1d971b4-ac67ca0d
# --------------------- Finish XML generator Function
# ======================================
# File number :  49
# File Name :  b1d9e136-6c94ea3f
# --------------------- Finish XML generator Function
# ======================================
# File number :  50
# File Name :  b1d9e136-9ab25cb3
# --------------------- Finish XML generator Function
# ======================================
# File number :  51
# File Name :  b1da9c53-0f3d4c5d
# --------------------- Finish XML generator Function
# ======================================
# File number :  52
# File Name :  b1dac7f7-6b2e0382
# --------------------- Finish XML generator Function
# ======================================
# File number :  53
# File Name :  b1db7e22-cfa74dc3
# --------------------- Finish XML generator Function
# ======================================
# File number :  54
# File Name :  b1dce572-c6a8cb5e
# --------------------- Finish XML generator Function
# ======================================
# File number :  55
# File Name :  b1dd58c1-8b546ba7
# --------------------- Finish XML generator Function
# ======================================
# File number :  56
# File Name :  b1df722f-57d21f3f
# --------------------- Finish XML generator Function
# ======================================
# File number :  57
# File Name :  b1df722f-5bcc3db7
# --------------------- Finish XML generator Function
# ======================================
# File number :  58
# File Name :  b1e0c01d-dd9e6e2f
# --------------------- Finish XML generator Function
# ======================================
# File number :  59
# File Name :  b1e1a7b8-0aec80e8
# --------------------- Finish XML generator Function
# ======================================
# File number :  60
# File Name :  b1e1a7b8-65ec7612
# --------------------- Finish XML generator Function
# ======================================
# File number :  61
# File Name :  b1e1a7b8-a7426a97
# --------------------- Finish XML generator Function
# ======================================
# File number :  62
# File Name :  b1e1a7b8-b397c445
# --------------------- Finish XML generator Function
# ======================================
# File number :  63
# File Name :  b1e2346e-c5f98707
# --------------------- Finish XML generator Function
# ======================================
# File number :  64
# File Name :  b1e3e9f5-92377424
# --------------------- Finish XML generator Function
# ======================================
# File number :  65
# File Name :  b1e62c91-eca210a9
# --------------------- Finish XML generator Function
# ======================================
# File number :  66
# File Name :  b1e6efc0-2552cc5d
# --------------------- Finish XML generator Function
# ======================================
# File number :  67
# File Name :  b1e88fd2-c1e4fd2b
# --------------------- Finish XML generator Function
# ======================================
# File number :  68
# File Name :  b1e8ad72-c3c79240
# --------------------- Finish XML generator Function
# ======================================
# File number :  69
# File Name :  b1e9ee0e-67e26f2e
# --------------------- Finish XML generator Function
# ======================================
# File number :  70
# File Name :  b1ea0ae4-4f770228
# --------------------- Finish XML generator Function
# ======================================
# File number :  71
# File Name :  b1eb9133-5cc75c18
# --------------------- Finish XML generator Function
# ======================================
# File number :  72
# File Name :  b1ebfc3c-740ec84a
# --------------------- Finish XML generator Function
# ======================================
# File number :  73
# File Name :  b1ebfc3c-cc9c2bb8
# --------------------- Finish XML generator Function
# ======================================
# File number :  74
# File Name :  b1ee702d-0ae1fc10
# --------------------- Finish XML generator Function
# ======================================
# File number :  75
# File Name :  b1ee702d-4a193906
# --------------------- Finish XML generator Function
# ======================================
# File number :  76
# File Name :  b1ee702d-525fcebf
# --------------------- Finish XML generator Function
# ======================================
# File number :  77
# File Name :  b1f022d3-3774de8b
# --------------------- Finish XML generator Function
# ======================================
# File number :  78
# File Name :  b1f022d3-45162c67
# --------------------- Finish XML generator Function
# ======================================
# File number :  79
# File Name :  b1f0efd9-37a14dda
# --------------------- Finish XML generator Function
# ======================================
# File number :  80
# File Name :  b1f0efd9-e900c6e5
# --------------------- Finish XML generator Function
# ======================================
# File number :  81
# File Name :  b1f20aa0-3401c3bf
# --------------------- Finish XML generator Function
# ======================================
# File number :  82
# File Name :  b1f20aa0-50213047
# --------------------- Finish XML generator Function
# ======================================
# File number :  83
# File Name :  b1f20aa0-6ef1db42
# --------------------- Finish XML generator Function
# ======================================
# File number :  84
# File Name :  b1f25ff6-1ddb7e43
# --------------------- Finish XML generator Function
# ======================================
# File number :  85
# File Name :  b1f4491b-07b32e8c
# --------------------- Finish XML generator Function
# ======================================
# File number :  86
# File Name :  b1f4491b-09593e90
# --------------------- Finish XML generator Function
# ======================================
# File number :  87
# File Name :  b1f4491b-16256d7c
# --------------------- Finish XML generator Function
# ======================================
# File number :  88
# File Name :  b1f4491b-33824f31
# --------------------- Finish XML generator Function
# ======================================
# File number :  89
# File Name :  b1f4491b-846d8cb2
# --------------------- Finish XML generator Function
# ======================================
# File number :  90
# File Name :  b1f4491b-97465266
# --------------------- Finish XML generator Function
# ======================================
# File number :  91
# File Name :  b1f4491b-9958bd99
# --------------------- Finish XML generator Function
# ======================================
# File number :  92
# File Name :  b1f4491b-bf7d513f
# --------------------- Finish XML generator Function
# ======================================
# File number :  93
# File Name :  b1f4491b-cf446195
# --------------------- Finish XML generator Function
# ======================================
# File number :  94
# File Name :  b1f4491b-d8d1459c
# --------------------- Finish XML generator Function
# ======================================
# File number :  95
# File Name :  b1f4491b-dd8dfed5
# --------------------- Finish XML generator Function
# ======================================
# File number :  96
# File Name :  b1f62c41-ed0c6521
# --------------------- Finish XML generator Function
# ======================================
# File number :  97
# File Name :  b1f6c103-5ce1f3c6
# --------------------- Finish XML generator Function
# ======================================
# File number :  98
# File Name :  b1f6c103-8b75ea3e
# --------------------- Finish XML generator Function
# ======================================
# File number :  99
# File Name :  b1f6c103-b00e8aad
# --------------------- Finish XML generator Function
# ======================================
# File number :  100
# File Name :  b1f85377-44885085
# --------------------- Finish XML generator Function
# ======================================
# File number :  101
# File Name :  b1fbaab8-68db7df7
# --------------------- Finish XML generator Function
# ======================================
# File number :  102
# File Name :  b1fbf878-b31a8293
# --------------------- Finish XML generator Function
# ======================================
# File number :  103
# File Name :  b1fc95c9-644e3c3f
# --------------------- Finish XML generator Function
# ======================================
# File number :  104
# File Name :  b1fc95c9-cb2882c7
# --------------------- Finish XML generator Function
# ======================================
# File number :  105
# File Name :  b1ff4656-0435391e
# --------------------- Finish XML generator Function
# ======================================
# File number :  106
# File Name :  b1ff4656-94ee8536
# --------------------- Finish XML generator Function
# ======================================
# File number :  107
# File Name :  b1ff4656-ebcfeb35
# --------------------- Finish XML generator Function
# ======================================
# File number :  108
# File Name :  b200b84e-4a792877
# --------------------- Finish XML generator Function
# ======================================
# File number :  109
# File Name :  b200e97a-bf074435
# --------------------- Finish XML generator Function
# ======================================
# File number :  110
# File Name :  b20234fd-822029be
# --------------------- Finish XML generator Function
# ======================================
# File number :  111
# File Name :  b202cae2-672e61c5
# --------------------- Finish XML generator Function
# ======================================
# File number :  112
# File Name :  b202cae2-f46c74a6
# --------------------- Finish XML generator Function
# ======================================
# File number :  113
# File Name :  b2036451-aa924fd1
# --------------------- Finish XML generator Function
# ======================================
# File number :  114
# File Name :  b2046bcf-8bc6a044
# --------------------- Finish XML generator Function
# ======================================
# File number :  115
# File Name :  b204a5c1-05981158
# --------------------- Finish XML generator Function
# ======================================
# File number :  116
# File Name :  b204a5c1-064b0040
# --------------------- Finish XML generator Function
# ======================================
# File number :  117
# File Name :  b204a5c1-fa3d5b88
# --------------------- Finish XML generator Function
# ======================================
# File number :  118
# File Name :  b205eb4d-f84aaa1a
# --------------------- Finish XML generator Function
# ======================================
# File number :  119
# File Name :  b2064e61-2beadd45
# --------------------- Finish XML generator Function
# ======================================
# File number :  120
# File Name :  b206a78b-99f405ab
# --------------------- Finish XML generator Function
# ======================================
# File number :  121
# File Name :  b2080dc7-f9b98a5f
# --------------------- Finish XML generator Function
# ======================================
# File number :  122
# File Name :  b20841f9-cef732d5
# --------------------- Finish XML generator Function
# ======================================
# File number :  123
# File Name :  b20b1e63-4d8478a4
# --------------------- Finish XML generator Function
# ======================================
# File number :  124
# File Name :  b20b69d2-64b9cdb8
# --------------------- Finish XML generator Function
# ======================================
# File number :  125
# File Name :  b20b69d2-650e674d
# --------------------- Finish XML generator Function
# ======================================
# File number :  126
# File Name :  b20b69d2-6e2b9e73
# --------------------- Finish XML generator Function
# ======================================
# File number :  127
# File Name :  b20b69d2-7767e6b6
# --------------------- Finish XML generator Function
# ======================================
# File number :  128
# File Name :  b20b69d2-bd242bf0
# --------------------- Finish XML generator Function
# ======================================
# File number :  129
# File Name :  b20b69d2-ca16c907
# --------------------- Finish XML generator Function
# ======================================
# File number :  130
# File Name :  b20b69d2-e31380a7
# --------------------- Finish XML generator Function
# ======================================
# File number :  131
# File Name :  b20b69d2-ffc1d6af
# --------------------- Finish XML generator Function
# ======================================
# File number :  132
# File Name :  b20b9c19-91e01a50
# --------------------- Finish XML generator Function
# ======================================
# File number :  133
# File Name :  b20d494a-cdebe83e
# --------------------- Finish XML generator Function
# ======================================
# File number :  134
# File Name :  b20e291a-32ac11c1
# --------------------- Finish XML generator Function
# ======================================
# File number :  135
# File Name :  b20e291a-6012d836
# --------------------- Finish XML generator Function
# ======================================
# File number :  136
# File Name :  b20eae11-149766ce
# --------------------- Finish XML generator Function
# ======================================
# File number :  137
# File Name :  b20eae11-18cd8ca2
# --------------------- Finish XML generator Function
# ======================================
# File number :  138
# File Name :  b20eae11-6817ba7a
# --------------------- Finish XML generator Function
# ======================================
# File number :  139
# File Name :  b20ff95c-b9444127
# --------------------- Finish XML generator Function
# ======================================
# File number :  140
# File Name :  b2102d00-5eb86b71
# --------------------- Finish XML generator Function
# ======================================
# File number :  141
# File Name :  b2102d00-a8c09be1
# --------------------- Finish XML generator Function
# ======================================
# File number :  142
# File Name :  b2131b7b-e58faab7
# --------------------- Finish XML generator Function
# ======================================
# File number :  143
# File Name :  b213e4eb-09c01a17
# --------------------- Finish XML generator Function
# ======================================
# File number :  144
# File Name :  b214d1e1-f248c616
# --------------------- Finish XML generator Function
# ======================================
# File number :  145
# File Name :  b21547c1-73e457f8
# --------------------- Finish XML generator Function
# ======================================
# File number :  146
# File Name :  b21547c1-796757ac
# --------------------- Finish XML generator Function
# ======================================
# File number :  147
# File Name :  b2156f8e-72e1547c
# --------------------- Finish XML generator Function
# ======================================
# File number :  148
# File Name :  b215943a-10e44587
# --------------------- Finish XML generator Function
# ======================================
# File number :  149
# File Name :  b216243d-55963da2
# --------------------- Finish XML generator Function
# ======================================
# File number :  150
# File Name :  b216243d-ad4306b9
# --------------------- Finish XML generator Function
# ======================================
# File number :  151
# File Name :  b2169b74-fa197951
# --------------------- Finish XML generator Function
# ======================================
# File number :  152
# File Name :  b21742c2-0e7a2b57
# --------------------- Finish XML generator Function
# ======================================
# File number :  153
# File Name :  b21742c2-18d3463a
# --------------------- Finish XML generator Function
# ======================================
# File number :  154
# File Name :  b2194b15-1825056a
# --------------------- Finish XML generator Function
# ======================================
# File number :  155
# File Name :  b21ac8b3-9b9cb45a
# --------------------- Finish XML generator Function
# ======================================
# File number :  156
# File Name :  b21bfb83-ea32f716
# --------------------- Finish XML generator Function
# ======================================
# File number :  157
# File Name :  b21c68e6-65674a17
# --------------------- Finish XML generator Function
# ======================================
# File number :  158
# File Name :  b21c86ac-0dc77d82
# --------------------- Finish XML generator Function
# ======================================
# File number :  159
# File Name :  b21c86ac-2eb7ba16
# --------------------- Finish XML generator Function
# ======================================
# File number :  160
# File Name :  b21c86ac-71205084
# --------------------- Finish XML generator Function
# ======================================
# File number :  161
# File Name :  b21d5efb-5e2cd743
# --------------------- Finish XML generator Function
# ======================================
# File number :  162
# File Name :  b2208b0f-2796a692
# --------------------- Finish XML generator Function
# ======================================
# File number :  163
# File Name :  b222c329-5dc8dbf7
# --------------------- Finish XML generator Function
# ======================================
# File number :  164
# File Name :  b229488e-e4714bb7
# --------------------- Finish XML generator Function
# ======================================
# File number :  165
# File Name :  b22a4d9f-48b2e986
# --------------------- Finish XML generator Function
# ======================================
# File number :  166
# File Name :  b22a4d9f-73cc8810
# --------------------- Finish XML generator Function
# ======================================
# File number :  167
# File Name :  b22e02cd-6af68e18
# --------------------- Finish XML generator Function
# ======================================
# File number :  168
# File Name :  b22f174d-a19c875e
# --------------------- Finish XML generator Function
# ======================================
# File number :  169
# File Name :  b22f385b-5d7e5202
# --------------------- Finish XML generator Function
# ======================================
# File number :  170
# File Name :  b230132b-ff8f2719
# --------------------- Finish XML generator Function
# ======================================
# File number :  171
# File Name :  b230a7b2-c881c382
# --------------------- Finish XML generator Function
# ======================================
# File number :  172
# File Name :  b231a630-c4522992
# --------------------- Finish XML generator Function
# ======================================
# File number :  173
# File Name :  b232c7c9-d251d9ee
# --------------------- Finish XML generator Function
# ======================================
# File number :  174
# File Name :  b2331b83-648e56ca
# --------------------- Finish XML generator Function
# ======================================
# File number :  175
# File Name :  b2331b83-a28e6b57
# --------------------- Finish XML generator Function
# ======================================
# File number :  176
# File Name :  b23493b1-3200de1c
# --------------------- Finish XML generator Function
# ======================================
# File number :  177
# File Name :  b237db93-fab44bf2
# --------------------- Finish XML generator Function
# ======================================
# File number :  178
# File Name :  b23a79d1-43dfeecd
# --------------------- Finish XML generator Function
# ======================================
# File number :  179
# File Name :  b23a79d1-e434acaa
# --------------------- Finish XML generator Function
# ======================================
# File number :  180
# File Name :  b23adb0d-72704b27
# --------------------- Finish XML generator Function
# ======================================
# File number :  181
# File Name :  b23adb0d-8a7aaced
# --------------------- Finish XML generator Function
# ======================================
# File number :  182
# File Name :  b23b2649-1a78948d
# --------------------- Finish XML generator Function
# ======================================
# File number :  183
# File Name :  b23b2649-6af03cd5
# --------------------- Finish XML generator Function
# ======================================
# File number :  184
# File Name :  b23b2649-8349d2a1
# --------------------- Finish XML generator Function
# ======================================
# File number :  185
# File Name :  b23bb45f-ddeea1d8
# --------------------- Finish XML generator Function
# ======================================
# File number :  186
# File Name :  b23c9e00-5506ddfb
# --------------------- Finish XML generator Function
# ======================================
# File number :  187
# File Name :  b23c9e00-b425de1b
# --------------------- Finish XML generator Function
# ======================================
# File number :  188
# File Name :  b23d2079-0c019d8e
# --------------------- Finish XML generator Function
# ======================================
# File number :  189
# File Name :  b23f7012-32d284ce
# --------------------- Finish XML generator Function
# ======================================
# File number :  190
# File Name :  b23f7012-fab06dac
# --------------------- Finish XML generator Function
# ======================================
# File number :  191
# File Name :  b23fe89b-c704fe97
# --------------------- Finish XML generator Function
# ======================================
# File number :  192
# File Name :  b24071b8-b3ee1196
# --------------------- Finish XML generator Function
# ======================================
# File number :  193
# File Name :  b2408e45-984ba5aa
# --------------------- Finish XML generator Function
# ======================================
# File number :  194
# File Name :  b242929f-3051abca
# --------------------- Finish XML generator Function
# ======================================
# File number :  195
# File Name :  b242f6b2-0033bdfb
# --------------------- Finish XML generator Function
# ======================================
# File number :  196
# File Name :  b242f6b2-99d2f2c1
# --------------------- Finish XML generator Function
# ======================================
# File number :  197
# File Name :  b242f6b2-eaa39345
# --------------------- Finish XML generator Function
# ======================================
# File number :  198
# File Name :  b242f6b2-f5da110f
# --------------------- Finish XML generator Function
# ======================================
# File number :  199
# File Name :  b24380ab-63272e5a
# --------------------- Finish XML generator Function
# ======================================
# File number :  200
# File Name :  b24380ab-6dbeb908
# --------------------- Finish XML generator Function
# ======================================
# File number :  201
# File Name :  b24380ab-855e9c00
# --------------------- Finish XML generator Function
# ======================================
# File number :  202
# File Name :  b24380ab-c07680d1
# --------------------- Finish XML generator Function
# ======================================
# File number :  203
# File Name :  b2443c9d-8cc3991f
# --------------------- Finish XML generator Function
# ======================================
# File number :  204
# File Name :  b245b306-ca3dca4e
# --------------------- Finish XML generator Function
# ======================================
# File number :  205
# File Name :  b245e52e-0a0e4e69
# --------------------- Finish XML generator Function
# ======================================
# File number :  206
# File Name :  b245e52e-aaeeb959
# --------------------- Finish XML generator Function
# ======================================
# File number :  207
# File Name :  b246c8e8-3dd42e6c
# --------------------- Finish XML generator Function
# ======================================
# File number :  208
# File Name :  b246c8e8-4dd36bfc
# --------------------- Finish XML generator Function
# ======================================
# File number :  209
# File Name :  b246c8e8-ecce1321
# --------------------- Finish XML generator Function
# ======================================
# File number :  210
# File Name :  b24702e3-0456c83c
# --------------------- Finish XML generator Function
# ======================================
# File number :  211
# File Name :  b24702e3-900f61ea
# --------------------- Finish XML generator Function
# ======================================
# File number :  212
# File Name :  b24702e3-e6f33768
# --------------------- Finish XML generator Function
# ======================================
# File number :  213
# File Name :  b24702e3-f56e0731
# --------------------- Finish XML generator Function
# ======================================
# File number :  214
# File Name :  b24702e3-fe617f57
# --------------------- Finish XML generator Function
# ======================================
# File number :  215
# File Name :  b248306f-a5089e94
# --------------------- Finish XML generator Function
# ======================================
# File number :  216
# File Name :  b2490dcb-7469cbe8
# --------------------- Finish XML generator Function
# ======================================
# File number :  217
# File Name :  b249e7f2-92d2efad
# --------------------- Finish XML generator Function
# ======================================
# File number :  218
# File Name :  b249e7f2-d619bd69
# --------------------- Finish XML generator Function
# ======================================
# File number :  219
# File Name :  b24b3585-221ac8ac
# --------------------- Finish XML generator Function
# ======================================
# File number :  220
# File Name :  b24bdca1-e4f0c558
# --------------------- Finish XML generator Function
# ======================================
# File number :  221
# File Name :  b24c9ee6-e43a6e8b
# --------------------- Finish XML generator Function
# ======================================
# File number :  222
# File Name :  b24ca67a-594d7d3c
# --------------------- Finish XML generator Function
# ======================================
# File number :  223
# File Name :  b24d283f-33783d1b
# --------------------- Finish XML generator Function
# ======================================
# File number :  224
# File Name :  b24f03f7-ff66eaca
# --------------------- Finish XML generator Function
# ======================================
# File number :  225
# File Name :  b24f7455-e8c55d6a
# --------------------- Finish XML generator Function
# ======================================
# File number :  226
# File Name :  b2505382-1423f56a
# --------------------- Finish XML generator Function
# ======================================
# File number :  227
# File Name :  b2505382-272e7823
# --------------------- Finish XML generator Function
# ======================================
# File number :  228
# File Name :  b2505382-2905b23c
# --------------------- Finish XML generator Function
# ======================================
# File number :  229
# File Name :  b2505382-549785d3
# --------------------- Finish XML generator Function
# ======================================
# File number :  230
# File Name :  b2505382-de5238f0
# --------------------- Finish XML generator Function
# ======================================
# File number :  231
# File Name :  b250fb0c-01a1b8d3
# --------------------- Finish XML generator Function
# ======================================
# File number :  232
# File Name :  b251064f-30002542
# --------------------- Finish XML generator Function
# ======================================
# File number :  233
# File Name :  b251064f-4696b75e
# --------------------- Finish XML generator Function
# ======================================
# File number :  234
# File Name :  b251064f-5f6b663e
# --------------------- Finish XML generator Function
# ======================================
# File number :  235
# File Name :  b251064f-8d92db81
# --------------------- Finish XML generator Function
# ======================================
# File number :  236
# File Name :  b251064f-e7a165fd
# --------------------- Finish XML generator Function
# ======================================
# File number :  237
# File Name :  b251b746-00138418
# --------------------- Finish XML generator Function
# ======================================
# File number :  238
# File Name :  b255cd6c-0bdf0ac7
# --------------------- Finish XML generator Function
# ======================================
# File number :  239
# File Name :  b255cd6c-2f889586
# --------------------- Finish XML generator Function
# ======================================
# File number :  240
# File Name :  b255cd6c-5ccba454
# --------------------- Finish XML generator Function
# ======================================
# File number :  241
# File Name :  b255cd6c-6502a28c
# --------------------- Finish XML generator Function
# ======================================
# File number :  242
# File Name :  b255cd6c-82c804d4
# --------------------- Finish XML generator Function
# ======================================
# File number :  243
# File Name :  b255cd6c-bc3cbb18
# --------------------- Finish XML generator Function
# ======================================
# File number :  244
# File Name :  b255cd6c-e5f99451
# --------------------- Finish XML generator Function
# ======================================
# File number :  245
# File Name :  b255cd6c-f2f28aff
# --------------------- Finish XML generator Function
# ======================================
# File number :  246
# File Name :  b255cd6c-fb594dcb
# --------------------- Finish XML generator Function
# ======================================
# File number :  247
# File Name :  b2576c8c-2924c365
# --------------------- Finish XML generator Function
# ======================================
# File number :  248
# File Name :  b2576c8c-2de20b8a
# --------------------- Finish XML generator Function
# ======================================
# File number :  249
# File Name :  b257f482-cf55d35c
# --------------------- Finish XML generator Function
# ======================================
# File number :  250
# File Name :  b258a38b-0126cc8c
# --------------------- Finish XML generator Function
# ======================================
# File number :  251
# File Name :  b258d359-49a3ad31
# --------------------- Finish XML generator Function
# ======================================
# File number :  252
# File Name :  b258d359-db99eff1
# --------------------- Finish XML generator Function
# ======================================
# File number :  253
# File Name :  b259c5e1-cda39ef9
# --------------------- Finish XML generator Function
# ======================================
# File number :  254
# File Name :  b25aac57-705d50ad
# --------------------- Finish XML generator Function
# ======================================
# File number :  255
# File Name :  b25ae6c0-311e72c2
# --------------------- Finish XML generator Function
# ======================================
# File number :  256
# File Name :  b25ae6c0-fb9fea6a
# --------------------- Finish XML generator Function
# ======================================
# File number :  257
# File Name :  b25c1103-5da4b435
# --------------------- Finish XML generator Function
# ======================================
# File number :  258
# File Name :  b25c51f5-e9dba941
# --------------------- Finish XML generator Function
# ======================================
# File number :  259
# File Name :  b25fb716-78d8d49b
# --------------------- Finish XML generator Function
# ======================================
# File number :  260
# File Name :  b25fd5d3-fa4bfca0
# --------------------- Finish XML generator Function
# ======================================
# File number :  261
# File Name :  b25fdb41-4644e3f7
# --------------------- Finish XML generator Function
# ======================================
# File number :  262
# File Name :  b262f576-b0373824
# --------------------- Finish XML generator Function
# ======================================
# File number :  263
# File Name :  b26309ce-447c0ac7
# --------------------- Finish XML generator Function
# ======================================
# File number :  264
# File Name :  b26309ce-fc963b47
# --------------------- Finish XML generator Function
# ======================================
# File number :  265
# File Name :  b26327fe-3ac19999
# --------------------- Finish XML generator Function
# ======================================
# File number :  266
# File Name :  b26331b9-102f5d9a
# --------------------- Finish XML generator Function
# ======================================
# File number :  267
# File Name :  b2638d82-062aa1de
# --------------------- Finish XML generator Function
# ======================================
# File number :  268
# File Name :  b263f57d-1ccf6e51
# --------------------- Finish XML generator Function
# ======================================
# File number :  269
# File Name :  b2648a7f-42f72f67
# --------------------- Finish XML generator Function
# ======================================
# File number :  270
# File Name :  b265b9cf-2d517da6
# --------------------- Finish XML generator Function
# ======================================
# File number :  271
# File Name :  b26610ce-083c3bd1
# --------------------- Finish XML generator Function
# ======================================
# File number :  272
# File Name :  b266429a-83757042
# --------------------- Finish XML generator Function
# ======================================
# File number :  273
# File Name :  b266429a-ac0c4ed3
# --------------------- Finish XML generator Function
# ======================================
# File number :  274
# File Name :  b266db29-12bf52fa
# --------------------- Finish XML generator Function
# ======================================
# File number :  275
# File Name :  b266db29-29fa8335
# --------------------- Finish XML generator Function
# ======================================
# File number :  276
# File Name :  b266db29-403143cc
# --------------------- Finish XML generator Function
# ======================================
# File number :  277
# File Name :  b266db29-4d22b355
# --------------------- Finish XML generator Function
# ======================================
# File number :  278
# File Name :  b266db29-c518f15d
# --------------------- Finish XML generator Function
# ======================================
# File number :  279
# File Name :  b266db29-da0abce7
# --------------------- Finish XML generator Function
# ======================================
# File number :  280
# File Name :  b2675b13-d04e4a76
# --------------------- Finish XML generator Function
# ======================================
# File number :  281
# File Name :  b268bb58-5ead8a56
# --------------------- Finish XML generator Function
# ======================================
# File number :  282
# File Name :  b2694461-db4f4470
# --------------------- Finish XML generator Function
# ======================================
# File number :  283
# File Name :  b26aafd1-1bc4dccc
# --------------------- Finish XML generator Function
# ======================================
# File number :  284
# File Name :  b26aafd1-513824d4
# --------------------- Finish XML generator Function
# ======================================
# File number :  285
# File Name :  b26ba07a-1c7593b1
# --------------------- Finish XML generator Function
# ======================================
# File number :  286
# File Name :  b26ba07a-203e440c
# --------------------- Finish XML generator Function
# ======================================
# File number :  287
# File Name :  b26ba07a-2b68a502
# --------------------- Finish XML generator Function
# ======================================
# File number :  288
# File Name :  b26ba07a-38f78442
# --------------------- Finish XML generator Function
# ======================================
# File number :  289
# File Name :  b26ba07a-c7bcbe2d
# --------------------- Finish XML generator Function
# ======================================
# File number :  290
# File Name :  b26ba07a-da78f324
# --------------------- Finish XML generator Function
# ======================================
# File number :  291
# File Name :  b26ba07a-e4ca935c
# --------------------- Finish XML generator Function
# ======================================
# File number :  292
# File Name :  b26ba07a-f781b661
# --------------------- Finish XML generator Function
# ======================================
# File number :  293
# File Name :  b26cfcdc-10346684
# --------------------- Finish XML generator Function
# ======================================
# File number :  294
# File Name :  b26cfcdc-2e290c42
# --------------------- Finish XML generator Function
# ======================================
# File number :  295
# File Name :  b26cfcdc-7b00747d
# --------------------- Finish XML generator Function
# ======================================
# File number :  296
# File Name :  b26cfcdc-eb092da8
# --------------------- Finish XML generator Function
# ======================================
# File number :  297
# File Name :  b26dd913-2888cbfd
# --------------------- Finish XML generator Function
# ======================================
# File number :  298
# File Name :  b26dddb5-28e4a05f
# --------------------- Finish XML generator Function
# ======================================
# File number :  299
# File Name :  b26f7271-d906ee87
# --------------------- Finish XML generator Function
# ======================================
# File number :  300
# File Name :  b26f8762-61cfb033
# --------------------- Finish XML generator Function
# ======================================
# File number :  301
# File Name :  b26f9b1e-09c56a3c
# --------------------- Finish XML generator Function
# ======================================
# File number :  302
# File Name :  b26f9b1e-3e172ced
# --------------------- Finish XML generator Function
# ======================================
# File number :  303
# File Name :  b27098c3-0db780d5
# --------------------- Finish XML generator Function
# ======================================
# File number :  304
# File Name :  b27098c3-915a9986
# --------------------- Finish XML generator Function
# ======================================
# File number :  305
# File Name :  b27098c3-c443b6e3
# --------------------- Finish XML generator Function
# ======================================
# File number :  306
# File Name :  b27098c3-dedf92b2
# --------------------- Finish XML generator Function
# ======================================
# File number :  307
# File Name :  b270d8e4-0f565398
# --------------------- Finish XML generator Function
# ======================================
# File number :  308
# File Name :  b27127df-eac9b95e
# --------------------- Finish XML generator Function
# ======================================
# File number :  309
# File Name :  b2714f5d-07bf604c
# --------------------- Finish XML generator Function
# ======================================
# File number :  310
# File Name :  b2714f5d-5bc98e55
# --------------------- Finish XML generator Function
# ======================================
# File number :  311
# File Name :  b2715214-13e3dd85
# --------------------- Finish XML generator Function
# ======================================
# File number :  312
# File Name :  b2715214-d38332ea
# --------------------- Finish XML generator Function
# ======================================
# File number :  313
# File Name :  b27369f3-9b9598f4
# --------------------- Finish XML generator Function
# ======================================
# File number :  314
# File Name :  b27369f3-dd3c0b46
# --------------------- Finish XML generator Function
# ======================================
# File number :  315
# File Name :  b2743b5d-e2d585be
# --------------------- Finish XML generator Function
# ======================================
# File number :  316
# File Name :  b2752cd6-12ba5588
# --------------------- Finish XML generator Function
# ======================================
# File number :  317
# File Name :  b275c028-6a0665cb
# --------------------- Finish XML generator Function
# ======================================
# File number :  318
# File Name :  b27688b6-1af27060
# --------------------- Finish XML generator Function
# ======================================
# File number :  319
# File Name :  b27688b6-cd521517
# --------------------- Finish XML generator Function
# ======================================
# File number :  320
# File Name :  b2778280-4179c4af
# --------------------- Finish XML generator Function
# ======================================
# File number :  321
# File Name :  b277a772-08d8d7ad
# --------------------- Finish XML generator Function
# ======================================
# File number :  322
# File Name :  b277a772-715e949c
# --------------------- Finish XML generator Function
# ======================================
# File number :  323
# File Name :  b277a772-848f75a9
# --------------------- Finish XML generator Function
# ======================================
# File number :  324
# File Name :  b277a772-87c10d5c
# --------------------- Finish XML generator Function
# ======================================
# File number :  325
# File Name :  b2794401-ba7d3c05
# --------------------- Finish XML generator Function
# ======================================
# File number :  326
# File Name :  b279bc06-3c8aeb90
# --------------------- Finish XML generator Function
# ======================================
# File number :  327
# File Name :  b279bc06-4fa57251
# --------------------- Finish XML generator Function
# ======================================
# File number :  328
# File Name :  b279bc06-b7bc42a9
# --------------------- Finish XML generator Function
# ======================================
# File number :  329
# File Name :  b27b0cd9-f184d9a3
# --------------------- Finish XML generator Function
# ======================================
# File number :  330
# File Name :  b27cd403-d7616bfa
# --------------------- Finish XML generator Function
# ======================================
# File number :  331
# File Name :  b27cd403-f2d087cc
# --------------------- Finish XML generator Function
# ======================================
# File number :  332
# File Name :  b27cde22-56abd0e1
# --------------------- Finish XML generator Function
# ======================================
# File number :  333
# File Name :  b27d5dcb-5bdec286
# --------------------- Finish XML generator Function
# ======================================
# File number :  334
# File Name :  b27d5dcb-856c0b43
# --------------------- Finish XML generator Function
# ======================================
# File number :  335
# File Name :  b27d5dcb-9230790c
# --------------------- Finish XML generator Function
# ======================================
# File number :  336
# File Name :  b27e8b69-c00092ae
# --------------------- Finish XML generator Function
# ======================================
# File number :  337
# File Name :  b27fdbad-ab895d86
# --------------------- Finish XML generator Function
# ======================================
# File number :  338
# File Name :  b27fdbad-ae939e31
# --------------------- Finish XML generator Function
# ======================================
# File number :  339
# File Name :  b280c9c1-4340305f
# --------------------- Finish XML generator Function
# ======================================
# File number :  340
# File Name :  b280c9c1-a75d23e5
# --------------------- Finish XML generator Function
# ======================================
# File number :  341
# File Name :  b2828509-133b042d
# --------------------- Finish XML generator Function
# ...
# --------------------- Finish XML generator Function
# ======================================
# File number :  9889
# File Name :  ca28f275-24384f38
# --------------------- Finish XML generator Function
# ======================================
# File number :  9890
# File Name :  ca28f275-95fc6836
# --------------------- Finish XML generator Function
# ======================================
# File number :  9891
# File Name :  ca28f275-ca28f770
# --------------------- Finish XML generator Function
# ======================================
# File number :  9892
# File Name :  ca28f275-cac4f254
# --------------------- Finish XML generator Function
# ======================================
# File number :  9893
# File Name :  ca28f275-df2e6ad2
# --------------------- Finish XML generator Function
# ======================================
# File number :  9894
# File Name :  ca297f76-c2ce18f5
# --------------------- Finish XML generator Function
# ======================================
# File number :  9895
# File Name :  ca29b7bd-0820fffb
# --------------------- Finish XML generator Function
# ======================================
# File number :  9896
# File Name :  ca2b7ab0-bfdc0fec
# --------------------- Finish XML generator Function
# ======================================
# File number :  9897
# File Name :  ca2ba838-fdddb1fb
# --------------------- Finish XML generator Function
# ======================================
# File number :  9898
# File Name :  ca2bcf0e-69e964d2
# --------------------- Finish XML generator Function
# ======================================
# File number :  9899
# File Name :  ca2c7c84-39bf84ee
# --------------------- Finish XML generator Function
# ======================================
# File number :  9900
# File Name :  ca2c7c84-5495c318
# --------------------- Finish XML generator Function
# ======================================
# File number :  9901
# File Name :  ca2c7c84-5902ee09
# --------------------- Finish XML generator Function
# ======================================
# File number :  9902
# File Name :  ca2c7c84-ba7685fc
# --------------------- Finish XML generator Function
# ======================================
# File number :  9903
# File Name :  ca2d1df6-54538d1a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9904
# File Name :  ca2d1df6-76d59c0c
# --------------------- Finish XML generator Function
# ======================================
# File number :  9905
# File Name :  ca2d32b3-5e8835ac
# --------------------- Finish XML generator Function
# ======================================
# File number :  9906
# File Name :  ca2fb80b-9d22e350
# --------------------- Finish XML generator Function
# ======================================
# File number :  9907
# File Name :  ca3045ee-a27490fa
# --------------------- Finish XML generator Function
# ======================================
# File number :  9908
# File Name :  ca3045ee-b8ab4712
# --------------------- Finish XML generator Function
# ======================================
# File number :  9909
# File Name :  ca3045ee-ec76b7c9
# --------------------- Finish XML generator Function
# ======================================
# File number :  9910
# File Name :  ca309fd3-10ac1488
# --------------------- Finish XML generator Function
# ======================================
# File number :  9911
# File Name :  ca309fd3-4a6f706c
# --------------------- Finish XML generator Function
# ======================================
# File number :  9912
# File Name :  ca309fd3-c485c1eb
# --------------------- Finish XML generator Function
# ======================================
# File number :  9913
# File Name :  ca309fd3-f767659b
# --------------------- Finish XML generator Function
# ======================================
# File number :  9914
# File Name :  ca3165e0-175d6f79
# --------------------- Finish XML generator Function
# ======================================
# File number :  9915
# File Name :  ca3165e0-3a330c98
# --------------------- Finish XML generator Function
# ======================================
# File number :  9916
# File Name :  ca3165e0-949dbfc8
# --------------------- Finish XML generator Function
# ======================================
# File number :  9917
# File Name :  ca3165e0-a8c1ce7a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9918
# File Name :  ca3165e0-c1c82c8f
# --------------------- Finish XML generator Function
# ======================================
# File number :  9919
# File Name :  ca319f4c-b34af0f1
# --------------------- Finish XML generator Function
# ======================================
# File number :  9920
# File Name :  ca326312-b648ccab
# --------------------- Finish XML generator Function
# ======================================
# File number :  9921
# File Name :  ca35c192-7f0eadba
# --------------------- Finish XML generator Function
# ======================================
# File number :  9922
# File Name :  ca3736db-3471ce50
# --------------------- Finish XML generator Function
# ======================================
# File number :  9923
# File Name :  ca3736db-ab6db00c
# --------------------- Finish XML generator Function
# ======================================
# File number :  9924
# File Name :  ca3736db-cc8e1fb7
# --------------------- Finish XML generator Function
# ======================================
# File number :  9925
# File Name :  ca3736db-cd087585
# --------------------- Finish XML generator Function
# ======================================
# File number :  9926
# File Name :  ca3736db-cf9e0cd4
# --------------------- Finish XML generator Function
# ======================================
# File number :  9927
# File Name :  ca3bbb0a-115a055f
# --------------------- Finish XML generator Function
# ======================================
# File number :  9928
# File Name :  ca3bbb0a-255bb069
# --------------------- Finish XML generator Function
# ======================================
# File number :  9929
# File Name :  ca3bbb0a-b711f4e3
# --------------------- Finish XML generator Function
# ======================================
# File number :  9930
# File Name :  ca3bbb0a-cd13da9e
# --------------------- Finish XML generator Function
# ======================================
# File number :  9931
# File Name :  ca3bf9b0-55d6ae41
# --------------------- Finish XML generator Function
# ======================================
# File number :  9932
# File Name :  ca3bf9b0-ab1201eb
# --------------------- Finish XML generator Function
# ======================================
# File number :  9933
# File Name :  ca3e6e3d-cc5275dd
# --------------------- Finish XML generator Function
# ======================================
# File number :  9934
# File Name :  ca3e6e3d-f66373c8
# --------------------- Finish XML generator Function
# ======================================
# File number :  9935
# File Name :  ca3f4c16-add215c4
# --------------------- Finish XML generator Function
# ======================================
# File number :  9936
# File Name :  ca3f4c16-b33f3a0b
# --------------------- Finish XML generator Function
# ======================================
# File number :  9937
# File Name :  ca4071a6-6fa1a1c8
# --------------------- Finish XML generator Function
# ======================================
# File number :  9938
# File Name :  ca40ddd3-102f3b02
# --------------------- Finish XML generator Function
# ======================================
# File number :  9939
# File Name :  ca40ddd3-f81f28e9
# --------------------- Finish XML generator Function
# ======================================
# File number :  9940
# File Name :  ca4269e1-0f1e4f92
# --------------------- Finish XML generator Function
# ======================================
# File number :  9941
# File Name :  ca4269e1-80c4e87b
# --------------------- Finish XML generator Function
# ======================================
# File number :  9942
# File Name :  ca4269e1-914f1061
# --------------------- Finish XML generator Function
# ======================================
# File number :  9943
# File Name :  ca4269e1-a3a6e21a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9944
# File Name :  ca4269e1-db6d731e
# --------------------- Finish XML generator Function
# ======================================
# File number :  9945
# File Name :  ca430005-edb0085d
# --------------------- Finish XML generator Function
# ======================================
# File number :  9946
# File Name :  ca430d8c-0b371423
# --------------------- Finish XML generator Function
# ======================================
# File number :  9947
# File Name :  ca455727-92566d05
# --------------------- Finish XML generator Function
# ======================================
# File number :  9948
# File Name :  ca479701-2ab57f9a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9949
# File Name :  ca4bdfab-34ec6a3a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9950
# File Name :  ca509e4e-a3166aa9
# --------------------- Finish XML generator Function
# ======================================
# File number :  9951
# File Name :  ca513280-e4ec496c
# --------------------- Finish XML generator Function
# ======================================
# File number :  9952
# File Name :  ca52e79f-eca3eeec
# --------------------- Finish XML generator Function
# ======================================
# File number :  9953
# File Name :  ca546e6d-852f3913
# --------------------- Finish XML generator Function
# ======================================
# File number :  9954
# File Name :  ca551156-5999d6d4
# --------------------- Finish XML generator Function
# ======================================
# File number :  9955
# File Name :  ca551156-fb7d1680
# --------------------- Finish XML generator Function
# ======================================
# File number :  9956
# File Name :  ca55fb23-6aec0f71
# --------------------- Finish XML generator Function
# ======================================
# File number :  9957
# File Name :  ca55fb23-83a86167
# --------------------- Finish XML generator Function
# ======================================
# File number :  9958
# File Name :  ca55fb23-f91ca9ad
# --------------------- Finish XML generator Function
# ======================================
# File number :  9959
# File Name :  ca561e94-8f719a63
# --------------------- Finish XML generator Function
# ======================================
# File number :  9960
# File Name :  ca561e94-d40cddf8
# --------------------- Finish XML generator Function
# ======================================
# File number :  9961
# File Name :  ca56690a-05ed80e9
# --------------------- Finish XML generator Function
# ======================================
# File number :  9962
# File Name :  ca56898d-f6400cb3
# --------------------- Finish XML generator Function
# ======================================
# File number :  9963
# File Name :  ca587a24-113bd37a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9964
# File Name :  ca5925b8-ca06566b
# --------------------- Finish XML generator Function
# ======================================
# File number :  9965
# File Name :  ca59adc8-62801139
# --------------------- Finish XML generator Function
# ======================================
# File number :  9966
# File Name :  ca59adc8-9001648c
# --------------------- Finish XML generator Function
# ======================================
# File number :  9967
# File Name :  ca59adc8-d7551f95
# --------------------- Finish XML generator Function
# ======================================
# File number :  9968
# File Name :  ca5e947c-c2f1d14b
# --------------------- Finish XML generator Function
# ======================================
# File number :  9969
# File Name :  ca5e947c-c6ac10fd
# --------------------- Finish XML generator Function
# ======================================
# File number :  9970
# File Name :  ca5f8e49-0df2e0a1
# --------------------- Finish XML generator Function
# ======================================
# File number :  9971
# File Name :  ca5fba82-4e60d94e
# --------------------- Finish XML generator Function
# ======================================
# File number :  9972
# File Name :  ca6142b4-ef037b5b
# --------------------- Finish XML generator Function
# ======================================
# File number :  9973
# File Name :  ca6170df-1893979a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9974
# File Name :  ca6170df-a566823d
# --------------------- Finish XML generator Function
# ======================================
# File number :  9975
# File Name :  ca6170df-c1a75664
# --------------------- Finish XML generator Function
# ======================================
# File number :  9976
# File Name :  ca6412a2-3db85e24
# --------------------- Finish XML generator Function
# ======================================
# File number :  9977
# File Name :  ca656c47-876ad414
# --------------------- Finish XML generator Function
# ======================================
# File number :  9978
# File Name :  ca656c47-e483f464
# --------------------- Finish XML generator Function
# ======================================
# File number :  9979
# File Name :  ca679a1e-a680fd14
# --------------------- Finish XML generator Function
# ======================================
# File number :  9980
# File Name :  ca679a1e-b92f424d
# --------------------- Finish XML generator Function
# ======================================
# File number :  9981
# File Name :  ca679a1e-cee7f0bc
# --------------------- Finish XML generator Function
# ======================================
# File number :  9982
# File Name :  ca68e8b3-3ecd270a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9983
# File Name :  ca6927ab-497d6b29
# --------------------- Finish XML generator Function
# ======================================
# File number :  9984
# File Name :  fe189115-9981a740
# --------------------- Finish XML generator Function
# ======================================
# File number :  9985
# File Name :  fe189115-9cc4a501
# --------------------- Finish XML generator Function
# ======================================
# File number :  9986
# File Name :  fe189115-adbd209a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9987
# File Name :  fe189115-c31cac5a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9988
# File Name :  fe189115-cfad8fcf
# --------------------- Finish XML generator Function
# ======================================
# File number :  9989
# File Name :  fe194677-e2d2ac8c
# --------------------- Finish XML generator Function
# ======================================
# File number :  9990
# File Name :  fe1b3799-a7863feb
# --------------------- Finish XML generator Function
# ======================================
# File number :  9991
# File Name :  fe1b92a1-faaaa1eb
# --------------------- Finish XML generator Function
# ======================================
# File number :  9992
# File Name :  fe1cc363-a3f36598
# --------------------- Finish XML generator Function
# ======================================
# File number :  9993
# File Name :  fe1d74f0-5cdc4057
# --------------------- Finish XML generator Function
# ======================================
# File number :  9994
# File Name :  fe1d74f0-6969bdb5
# --------------------- Finish XML generator Function
# ======================================
# File number :  9995
# File Name :  fe1d9184-cd999efe
# --------------------- Finish XML generator Function
# ======================================
# File number :  9996
# File Name :  fe1d9184-d144106a
# --------------------- Finish XML generator Function
# ======================================
# File number :  9997
# File Name :  fe1d9184-dec09b65
# --------------------- Finish XML generator Function
# ======================================
# File number :  9998
# File Name :  fe1f2409-5b415eb7
# --------------------- Finish XML generator Function
# ======================================
# File number :  9999
# File Name :  fe1f2409-c16ea1ed
# --------------------- Finish XML generator Function
# ======================================
# File number :  10000
# File Name :  fe1f55fa-19ba3600
# --------------------- Finish XML generator Function
# counter_Error_indicator :  0

# %% [markdown]
# ## Looping over the data set folder to remove any image that doesn't has a similar annotation XML file

# %%
image_folder = "val"
annotation_folder = "annotations"
counter_Error_indicator = 0
unrelated_images_folder_path = 'unrelated_images_folder' 

for filename in os.listdir(image_folder):
    if filename.endswith(".jpg"):   # filter by image extension if needed
        image_path = os.path.join(image_folder, filename)
        annotation_path = os.path.join(annotation_folder, filename.split('.')[0] + '.xml')
        
        if not os.path.isfile(annotation_path):
            counter_Error_indicator = counter_Error_indicator+1
            print('======================================')
            print(f"No annotation file found for {image_path}")
            # so move that image which has no annotaion to unrelated_images_folder
            shutil.move(image_path, unrelated_images_folder_path)

            
print("counter_Error_indicator : ", counter_Error_indicator)
# Out:
# counter_Error_indicator :  0
